# %%
import pandas as pd
import numpy as np

# %%
# !pip install datasets pandas

# %%
from datasets import load_dataset

# %%
dataset = load_dataset("DFKI-SLT/science_ie")

# %%
df = pd.DataFrame(dataset['train'])
display(df.head())
