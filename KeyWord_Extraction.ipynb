# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# --- System & Environment ---
import pandas as pd
import numpy as np
from google.colab import drive
from IPython.display import display

# --- Role 2: Data Engineering ---
from datasets import load_dataset

# --- Role 3: Classical NLP (TF-IDF) ---
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer

# Download necessary NLTK dictionaries
nltk.download('punkt')
nltk.download('stopwords')

# --- Role 4: Advanced NLP (BERT) ---
from keybert import KeyBERT
import torch
from transformers import AutoTokenizer, AutoModel  # If you decide to look under the hood

print("✅ All libraries successfully imported and ready!")

# %%
df = pd.read_csv('/content/drive/MyDrive/KeyWord_Extraction/data/science_ie_dataset.csv')

# %%
display(df.head())
# Out:
#                   id                                               text  \
# 0  S221266781300018X  Amodel are proposed for modeling data-centric ...
# 1  S000926141301539X  In this Letter we revisit the Chesnavich model...
# 2  S0009261412013838  Experimental studies of the dynamics of indivi...
# 3  S0927025612000249  The need for power generation industry to impr...
# 4  S003238610900086X  We deal with the intensity scattered by a rand...
#
#                                           keyphrases  \
# 0  [{'id': 'T1', 'start': 24, 'end': 58, 'type': ...
# 1  [{'id': 'T1', 'start': 140, 'end': 162, 'type'...
# 2  [{'id': 'T1', 'start': 51, 'end': 63, 'type': ...
# 3  [{'id': 'T1', 'start': 13, 'end': 29, 'type': ...
# 4  [{'id': 'T1', 'start': 84, 'end': 93, 'type': ...
#
#                                            relations
# 0  [{'arg1': 'T4', 'arg2': 'T3', 'relation': 1, '...
# 1  [{'arg1': 'T6', 'arg2': 'T11', 'relation': 1, ...
# ...
